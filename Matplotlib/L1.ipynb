# %% [markdown]
# # Bar Plot

# %%
import matplotlib.pyplot as plt

# %%
x=['python','c','c++','java']
y=[85,70,60,82]
plt.xlabel('languages')
plt.ylabel('popularity')
plt.title('data')
plt.bar(x,y)
plt.show()
