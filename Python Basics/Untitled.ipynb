# %%
class kalp:
    def __init__(self,l):
        self.l=l

# %%
n1='kalp'
n2='zeel'
s="my name is {my} and my frd name is {ur}".format(my=n1,ur=n2)

# %%
s
# Out:
# 'my name is kalp and my frd name is zeel'

# %%
input("take an input")
# Out:
# take an input 1
# '1'
